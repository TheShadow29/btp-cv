# %%
from all_imports import *

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from ptbds import *
from metrics import *

# %%
from nets import get_graph_senet_small

# %%
snt_mdl = get_graph_senet_small()
snt_mdl = to_gpu(snt_mdl)
learn = ConvLearner.from_model_data(snt_mdl, gdata)

# %%
learn.fit(1e-1, 2, cycle_len=10, best_save_name='Gcnn1_ecg1', metrics=[accuracy, actual_acc])
# Out:
# ...
#   0%|          | 0/168 [00:00<?, ?it/s]> /home/arka/Ark_files/btp-cv/code/gcn_fai/nets.py(63)forward()
# -> x = x.view([B, V, self.out_c])             # B x V x Fout
# (Pdb) x.shape
# torch.Size([240, 1])
# (Pdb) self.lin
# Linear(in_features=16, out_features=1, bias=True)
# (Pdb) self.lin(x)
# *** RuntimeError: size mismatch at /opt/conda/conda-bld/pytorch_1518244421288/work/torch/lib/THC/generic/THCTensorMathBlas.cu:247
# (Pdb) x
# Variable containing:
#  -861.6171
# -1144.5366
# -1159.4875
# -1178.4537
# -1216.0060
# -1347.7634
# -1115.4299
# -1061.4324
# -1220.5457
# -1025.1775
# -1344.5137
# -1574.1329
# -1490.0204
# -1141.7090
# -1162.9957
#    22.4735
#    29.9406
#    30.2994
#    30.8169
#    31.8120
#    35.1950
#    29.1265
#    27.7103
#    31.8986
#    26.7874
#    35.0839
#    41.0951
#    38.9549
#    29.8628
#    30.4119
# -1427.0599
# -1895.6708
# -1920.2765
# -1951.8990
# -2013.9521
# -2232.3892
# -1847.3885
# -1758.1152
# -2021.6173
# -1697.8210
# -2227.0515
# ...

# %%
# %debug
