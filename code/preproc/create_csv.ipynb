# %%
import pandas as pd

# %%
from pathlib import Path

# %%
train_csv_file = Path('./train.csv')

# %%
traincsv = pd.read_csv(train_csv_file, usecols=[1, 4])

# %%
traincsv.replace('\s', '-', regex=True)

# %%
train_csv = traincsv.replace('/', '_', regex=True)

# %%
traincsv.to_csv('train_only_labels.csv', index=False)

# %%
def all_cols_to_only_labels(inp_csv_file, outp_csv_file):
    inp_csv = pd.read_csv(inp_csv_file, usecols=[1, 5])
    inp_csv = inp_csv.replace('/', '_', regex=True)
    inp_csv.to_csv(outp_csv_file, index=False)

# %%
def all_cols_to_only_labels_name(inp_csv_file, outp_csv_file):
    inp_csv = pd.read_csv(inp_csv_file, usecols=[1, 4])
    inp_csv = inp_csv.replace('/', '_', regex=True)
    inp_csv = inp_csv.replace('\s', '-', regex=True)
    inp_csv.to_csv(outp_csv_file, index=False)

# %%
all_cols_to_only_labels(Path('./train.csv'), Path('./train_only_labels.csv'))

# %%
all_cols_to_only_labels(Path('./val.csv'), Path('./val_only_labels.csv'))

# %%
all_cols_to_only_labels(Path('./test.csv'), Path('./test_only_labels.csv'))

# %%
all_cols_to_only_labels_name(Path('./train.csv'), Path('./train_labels_name.csv'))
all_cols_to_only_labels_name(Path('./val.csv'), Path('./val_labels_name.csv'))
all_cols_to_only_labels_name(Path('./test.csv'), Path('./test_labels_name.csv'))

# %%
tcsv = pd.read_csv(Path('./train_only_labels.csv'))

# %%
import json

dct = json.load(Path('./locdisease_map.json').open())

dct
# Out:
# {'Myocardial infarction|infero-latera': 0,
#  'Myocardial infarction|anterior': 1,
#  'Myocardial infarction|infero-postero-lateral': 2,
#  'Myocardial infarction|antero-septal': 3,
#  'Myocardial infarction|inferior': 4,
#  'Myocardial infarction|infero-lateral': 5,
#  'Myocardial infarction|infero-poster-lateral': 6,
#  'Myocardial infarction|antero-lateral': 7,
#  'Myocardial infarction|lateral': 8,
#  'Myocardial infarction|postero-lateral': 9,
#  'Myocardial infarction|posterior': 10,
#  'Myocardial infarction|no': 11,
#  'Healthy control|no': 12,
#  'Valvular heart disease|no': 13,
#  'Myocardial infarction|infero-posterior': 14,
#  'Dysrhythmia|no': 15,
#  'Heart failure (NYHA 2)|no': 16,
#  'Heart failure (NYHA 3)|no': 17,
#  'Heart failure (NYHA 4)|no': 18,
#  'Palpitation|no': 19,
#  'Cardiomyopathy|no': 20,
#  'Stable angina|no': 21,
#  'Myocardial infarction|antero-septo-lateral': 22,
#  'Hypertrophy|no': 23,
#  'Bundle branch block|no': 24,
#  'Unstable angina|no': 25,
#  'Bundle branch block|unknown': 26,
#  'Myocarditis|no': 27}

# %%
PATH = Path('/scratch/arka/Ark_git_files/ecg_data/')

# %%
tcsv = pd.read_csv(train_csv_file)

# %%
tcsv = tcsv.replace('/', '_', regex=True)
tcsv = tcsv.replace('\s', '-', regex=True)

# %%
tcsv
# Out:
#      Unnamed: 0                    0                 Disease  \
# 0           261  patient088_s0352lre   Myocardial-infarction
# 1           259  patient088_s0339lre   Myocardial-infarction
# 2           544  patient292_s0555_re   Myocardial-infarction
# 3           205  patient073_s0249lre   Myocardial-infarction
# 4           344  patient130_s0166_re           Stable-angina
# 5           307  patient099_s0419lre   Myocardial-infarction
# 309                inferior                Myocardial-infarction|inferior
# 310   infero-poster-lateral   Myocardial-infarction|infero-poster-lateral
# 311          antero-lateral          Myocardial-infarction|antero-lateral
# 312           antero-septal           Myocardial-infarction|antero-septal
#
#      Loc_Disease_label  Disease_label
# 0                    4              1
# 1                    4              1
# 2                    7              1
# 3                    7              1
# 5                    7              1
# 8                    4              1
# 9                    4              1
# 10                   5              1
# 11                   3              1
# 12                   7              1
# 13                   7              1
# 14                   4              1
# 15                  12              0
# 16                   4              1
# 18                  11              1
# 20                  12              0
# 21                   2              1
# 22                   6              1
# 23                  12              0
# 24                   7              1
# 25                   2              1
# 26                   5              1
# 27                  12              0
# 28                   4              1
# 29                   4              1
# 30                   5              1
# 31                  10              1
# 32                   7              1
# 33                   4              1
# 34                  12              0
# ..                 ...            ...
# 280                  7              1
# 281                  7              1
# 282                  7              1
# 283                  4              1
# 284                  4              1
# 286                  4              1
# 288                 12              0
# 289                  4              1
# 290                  3              1
# 291                 12              0
# 292                 12              0
# 293                  3              1
# 294                 12              0
# 295                  4              1
# 296                  5              1
# 297                  5              1
# 298                  3              1
# 299                  3              1
# 300                  2              1
# 301                  1              1
# 302                  1              1
# 304                  1              1
# 305                  5              1
# 306                  5              1
# 307                  1              1
# 308                 12              0
# 309                  4              1
# 310                  6              1
# 311                  7              1
# 312                  3              1
#
# [268 rows x 7 columns]

# %%
def all_cols_to_only_labels_gami(inp_file, outp_file):
    tcsv = pd.read_csv(inp_file, usecols=[1, 5])
    tcsv = tcsv.replace('/', '_', regex=True)
    out_csv = tcsv[tcsv['Loc_Disease_label'].isin([1,3, 7, 12])]
    out_csv.to_csv(outp_file, index=False)

# %%
def all_cols_to_only_two_class_labels_gami(inp_file, outp_file):
    tcsv = pd.read_csv(inp_file, usecols=[1, 2])
    tcsv = tcsv.replace('/', '_', regex=True)
    tcsv = tcsv.replace('\s', '-', regex=True)
#     out_csv = tcsv[tcsv['Loc_Disease_label'].isin([1,3, 7, 12])]
    out_csv = tcsv[tcsv['Disease'].isin(['Myocardial-infarction', 'Healthy-control'])]
    out_csv['Disease_label'] = out_csv['Disease'].apply(lambda x: dis_label[x])
    out_csv.to_csv(outp_file, index=False, columns=['0', 'Disease_label'])

# %%
all_cols_to_only_labels_gami(Path('./train.csv'), PATH / 'train_only_labels_id_gami.csv')

all_cols_to_only_labels_gami(Path('./val.csv'), PATH / 'val_only_labels_id_gami.csv')

all_cols_to_only_labels_gami(Path('./test.csv'), PATH / 'test_only_labels_id_gami.csv')

# %%
all_cols_to_only_two_class_labels_gami(Path('./train.csv'), PATH / 'train_only_two_class_labels_id_gami.csv')

all_cols_to_only_two_class_labels_gami(Path('./val.csv'), PATH / 'val_only_two_class_labels_id_gami.csv')

all_cols_to_only_two_class_labels_gami(Path('./test.csv'), PATH / 'test_only_two_class_labels_id_gami.csv')
# Out:
# /scratch/arka/miniconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
t1 = pd.read_csv(PATH / 'train_only_two_class_labels_id_gami.csv')

t1.groupby('Disease_label').agg([len])

# %%
t1 = pd.read_csv(PATH / 'val_only_two_class_labels_id_gami.csv')

t1.groupby('Disease_label').agg([len])
# Out:
#                 0
#               len
# Disease_label
# 0              14
# 1              70
